# %% [markdown]
# # Team Pandas Series

# %%
# imports
import numpy as np
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 1: How to create a series from a list, numpy array and dict?
#
# Create a pandas series from each of the items below: a list, numpy and a dictionary

# %%
# Your code

mylist = list('abcde')
myarr = np.arange(5)
mydict = dict(zip(mylist, myarr))

# %%
my_list = pd.Series(mylist)
my_arr = pd.Series(myarr)
my_dict= pd.Series(mydict)

# %%
# Solution

print(mylistserie)
print(myarrserie)
print(mydictserie)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int32
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int32

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 2: How to get the items of series A not present in series B?
#
# From ser1 remove items present in ser2.

# %%
# Your code

ser1 = pd.Series([1, 2, 3, 4, 5])
ser2 = pd.Series([4, 5, 6, 7, 8])

# %%
ser1[~ser1.isin(ser2)]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# Solution

ser1
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 3: How to bin a numeric series to 10 groups of equal size?
#
# Bin the series ser into 10 equal deciles and replace the values with the bin name.

# %%
# Your code
ser = pd.Series(np.random.random(20))
bins = pd.qcut(ser,
        q=[0, .10, .20, .3, .4, .5, .6, .7, .8, .9, 1],
        labels=['1st', '2nd', '3rd', '4th', '5th', '6th', '7th', '8th', '9th', '10th'])
print(bins.head())
# Out:
# 0    1st
# 1    7th
# 2    2nd
# 3    3rd
# 4    6th
# dtype: category
# Categories (10, object): ['1st' < '2nd' < '3rd' < '4th' ... '7th' < '8th' < '9th' < '10th']

# %%
print(ser.head())
print(rank.head())
# Out:
# 0    0.401136
# 1    0.412973
# 2    0.796225
# 3    0.098745
# 4    0.204000
# dtype: float64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/v0/ywqslh_51dx3jnpnjr05wgsr0000gn/T/ipykernel_31549/4013563162.py in <module>
#       1 print(ser.head())
# ----> 2 print(rank.head())
#
# NameError: name 'rank' is not defined

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 4: How to convert a numpy array to a dataframe of given shape?
#
# Reshape the series ser into a dataframe with 7 rows and 5 columns.

# %%
# Your code 

ser = pd.Series(np.random.randint(1, 10, 35))
serpd = pd.DataFrame(ser.values.reshape(7,5))
serpd
# Out:
#    0  1  2  3  4
# 0  6  6  7  8  4
# 1  6  6  7  9  9
# 2  6  3  2  2  8
# 3  6  1  7  2  8
# 4  5  4  7  9  7
# 5  6  1  8  5  4
# 6  7  4  3  6  6

# %%
# Solution

serpd
# Out:
#    0  1  2  3  4
# 0  7  8  2  1  5
# 1  7  3  1  8  1
# 2  7  5  9  8  4
# 3  4  6  5  1  7
# 4  9  5  9  8  4
# 5  6  2  6  3  8
# 6  8  3  6  3  1

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 5: How to create a TimeSeries starting ‘2022-01-02’ and 10 weekends (sundays) after that, having random numbers as values?

# %%
# Your code

time_series = pd.Series(np.random.randint(1, 10, 10),  )
time_pd = pd.Series(np.random.randint(1,10,10), pd.date_range('2022-01-01', periods=10, freq='W-SAT'))

time_pd
# Out:
# 2022-01-01    5
# 2022-01-08    8
# 2022-01-15    5
# 2022-01-22    3
# 2022-01-29    5
# 2022-02-05    4
# 2022-02-12    2
# 2022-02-19    3
# 2022-02-26    8
# 2022-03-05    4
# Freq: W-SAT, dtype: int64

# %%
# Solution

time_series
# Out:
# 2022-01-02    2
# 2022-01-09    1
# 2022-01-16    9
# 2022-01-23    6
# 2022-01-30    3
# 2022-02-06    7
# 2022-02-13    9
# 2022-02-20    7
# 2022-02-27    9
# 2022-03-06    5
# Freq: W-SUN, dtype: int32

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 6: How to change column values when importing csv to a dataframe?
#
# Import the boston housing dataset, but while importing change the 'medv' (median house value) column so that values < 25 becomes ‘Low’ and > 25 becomes ‘High’.

# %%
# Your code

url = 'https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv'
df = pd.read_csv(url,
                 converters={'medv': lambda x: 'High' if float(x) > 25 else 'Low'}              #-> converters !!!
                 )

# %%
# Solution

df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98   Low
# 1       17.8  396.90   9.14   Low
# 2       17.8  392.83   4.03  High
# 3       18.7  394.63   2.94  High
# 4       18.7  396.90   5.33  High
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67   Low
# 502     21.0  396.90   9.08   Low
# 503     21.0  396.90   5.64   Low
# 504     21.0  393.45   6.48   Low
# 505     21.0  396.90   7.88   Low
#
# [506 rows x 14 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 7: How to get the nrows, ncolumns, datatype, summary stats of each column of a dataframe?
#
# Get the number of rows, columns, datatype and summary statistics of each column of the Cars93 dataset.

# %%
# Your code

url = 'https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv'

df.shape[0]

df.shape[1]

df.dtypes

df.get_dtype_counts()
df.dtypes.value_counts()
df.describe()
df.describe(include="all")

df_arr = df.values
print(df_arr)

df_list = df.values.tolist()
print(df_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/v0/ywqslh_51dx3jnpnjr05wgsr0000gn/T/ipykernel_31549/3756326996.py in <module>
#       9 df.dtypes
#      10
# ---> 11 df.get_dtype_counts()
#      12 df.dtypes.value_counts()
#      13 df.describe()
#
# ~/miniconda3/envs/ironhack/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_dtype_counts'

# %%
# Solution

print(numberofcols)
print(numberofrows)
print(datatype)
print(summarystats)
# Out:
# 27
# 93
# Manufacturer           object
# Model                  object
# Type                   object
# Min.Price             float64
# Price                 float64
# Max.Price             float64
# MPG.city              float64
# MPG.highway           float64
# AirBags                object
# DriveTrain             object
# Cylinders              object
# EngineSize            float64
# Horsepower            float64
# RPM                   float64
# Rev.per.mile          float64
# Man.trans.avail        object
# Fuel.tank.capacity    float64
# Passengers            float64
# Length                float64
# Wheelbase             float64
# Width                 float64
# Turn.circle           float64
# Rear.seat.room        float64
# Luggage.room          float64
# Weight                float64
# Origin                 object
# Make                   object
# dtype: object
#        Min.Price      Price  Max.Price   MPG.city  MPG.highway  EngineSize  \
# count  86.000000  91.000000  88.000000  84.000000    91.000000   91.000000
# mean   17.118605  19.616484  21.459091  22.404762    29.065934    2.658242
# std     8.828290   9.724280  10.696563   5.841520     5.370293    1.045845
# min     6.700000   7.400000   7.900000  15.000000    20.000000    1.000000
# 25%    10.825000  12.350000  14.575000  18.000000    26.000000    1.800000
# 50%    14.600000  17.700000  19.150000  21.000000    28.000000    2.300000
# 75%    20.250000  23.500000  24.825000  25.000000    31.000000    3.250000
# max    45.400000  61.900000  80.000000  46.000000    50.000000    5.700000
#
#        Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  \
# count   86.000000    90.000000     87.000000           85.000000   91.000000
# mean   144.000000  5276.666667   2355.000000           16.683529    5.076923
# std     53.455204   605.554811    486.916616            3.375748    1.045953
# min     55.000000  3800.000000   1320.000000            9.200000    2.000000
# 25%    100.750000  4800.000000   2017.500000           14.500000    4.000000
# 50%    140.000000  5200.000000   2360.000000           16.500000    5.000000
# 75%    170.000000  5787.500000   2565.000000           19.000000    6.000000
# max    300.000000  6500.000000   3755.000000           27.000000    8.000000
#
#            Length   Wheelbase      Width  Turn.circle  Rear.seat.room  \
# count   89.000000   92.000000  87.000000    88.000000       89.000000
# mean   182.865169  103.956522  69.448276    38.954545       27.853933
# std     14.792651    6.856317   3.778023     3.304157        3.018129
# min    141.000000   90.000000  60.000000    32.000000       19.000000
# 25%    174.000000   98.000000  67.000000    36.000000       26.000000
# 50%    181.000000  103.000000  69.000000    39.000000       27.500000
# 75%    192.000000  110.000000  72.000000    42.000000       30.000000
# max    219.000000  119.000000  78.000000    45.000000       36.000000
#
#        Luggage.room       Weight
# count     74.000000    86.000000
# mean      13.986486  3104.593023
# std        3.120824   600.129993
# min        6.000000  1695.000000
# 25%       12.000000  2647.500000
# 50%       14.000000  3085.000000
# 75%       16.000000  3567.500000
# max       22.000000  4105.000000

# %% [markdown]
# ---

# %% [markdown]
# ### Kombat 8: How to slice a DataFrame by column value?
#
# Get every Chevrolet car with a Horsepower lower than 3.0 from the Cars93 dataset.

# %%
# Your code

url = 'https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv'
df = pd.read_csv(url)
pd.set_option('display.max_columns', None)
df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain Cylinders  EngineSize  \
# 0          31.0                None      Front         4         1.8
# 1          25.0  Driver & Passenger      Front         6         3.2
# 2          26.0         Driver only      Front         6         2.8
# 3          26.0  Driver & Passenger        NaN         6         NaN
# 4          30.0                 NaN       Rear         4         3.5
# ..          ...                 ...        ...       ...         ...
# 88         21.0                None      Front         5         2.5
# 89         30.0                None      Front         4         2.0
# 90         25.0                None      Front         6         2.8
# 91         28.0         Driver only       Rear       NaN         2.3
# 92         28.0  Driver & Passenger      Front         5         2.4
#
#     Horsepower     RPM  Rev.per.mile Man.trans.avail  Fuel.tank.capacity  \
# 0        140.0  6300.0        2890.0             Yes                13.2
# 1        200.0  5500.0        2335.0             Yes                18.0
# 2        172.0  5500.0        2280.0             Yes                16.9
# 3        172.0  5500.0        2535.0             NaN                21.1
# 4        208.0  5700.0        2545.0             Yes                21.1
# ..         ...     ...           ...             ...                 ...
# 88       109.0  4500.0        2915.0             Yes                21.1
# 89       134.0  5800.0        2685.0             Yes                18.5
# 90       178.0  5800.0        2385.0             Yes                18.5
# 91       114.0  5400.0        2215.0             Yes                15.8
# 92       168.0  6200.0           NaN             Yes                19.3
#
#     Passengers  Length  Wheelbase  Width  Turn.circle  Rear.seat.room  \
# 0          5.0   177.0      102.0   68.0         37.0            26.5
# 1          5.0   195.0      115.0   71.0         38.0            30.0
# 2          5.0   180.0      102.0   67.0         37.0            28.0
# 3          6.0   193.0      106.0    NaN         37.0            31.0
# 4          4.0   186.0      109.0   69.0         39.0            27.0
# ..         ...     ...        ...    ...          ...             ...
# 88         7.0   187.0      115.0   72.0         38.0            34.0
# 89         5.0   180.0      103.0   67.0         35.0            31.5
# 90         4.0   159.0       97.0   66.0         36.0            26.0
# 91         5.0   190.0      104.0   67.0         37.0            29.5
# 92         5.0   184.0      105.0   69.0         38.0            30.0
#
#     Luggage.room  Weight   Origin                Make
# 0            NaN  2705.0  non-USA       Acura Integra
# 1           15.0  3560.0  non-USA        Acura Legend
# 2           14.0  3375.0  non-USA             Audi 90
# 3           17.0  3405.0  non-USA            Audi 100
# 4           13.0  3640.0  non-USA            BMW 535i
# ..           ...     ...      ...                 ...
# 88           NaN  3960.0      NaN  Volkswagen Eurovan
# 89          14.0  2985.0  non-USA   Volkswagen Passat
# 90          15.0  2810.0  non-USA  Volkswagen Corrado
# 91          14.0  2985.0  non-USA           Volvo 240
# 92          15.0  3245.0  non-USA           Volvo 850
#
# [93 rows x 27 columns]

# %%
df_marca = df['Manufacturer'] == 'Chevrolet'
df_marca1 = df[df_marca]
df_marca1
# Out:
#    Manufacturer       Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 11    Chevrolet    Cavalier  Compact        8.5   13.4       18.3      25.0
# 12    Chevrolet     Corsica  Compact       11.4   11.4       11.4      25.0
# 13    Chevrolet      Camaro   Sporty       13.4   15.1       16.8      19.0
# 14    Chevrolet      Lumina  Midsize       13.4   15.9       18.4       NaN
# 15    Chevrolet  Lumina_APV      Van       14.7   16.3       18.0      18.0
# 16    Chevrolet       Astro      Van       14.7   16.6       18.6      15.0
# 17    Chevrolet     Caprice    Large       18.0   18.8       19.6      17.0
# 18    Chevrolet    Corvette   Sporty       34.6   38.0       41.5      17.0
#
#     MPG.highway             AirBags DriveTrain Cylinders  EngineSize  \
# 11         36.0                 NaN        NaN         4         2.2
# 12         34.0         Driver only      Front       NaN         2.2
# 13         28.0  Driver & Passenger       Rear       NaN         3.4
# 14         29.0                None      Front         4         2.2
# 15         23.0                None      Front         6         3.8
# 16         20.0                None        4WD         6         4.3
# 17         26.0         Driver only       Rear         8         5.0
# 18         25.0         Driver only       Rear         8         5.7
#
#     Horsepower     RPM  Rev.per.mile Man.trans.avail  Fuel.tank.capacity  \
# 11         NaN  5200.0        2380.0             Yes                15.2
# 12       110.0  5200.0        2665.0             Yes                15.6
# 13       160.0  4600.0        1805.0             Yes                 NaN
# 14         NaN  5200.0        2595.0              No                16.5
# 15       170.0  4800.0        1690.0              No                20.0
# 16         NaN  4000.0        1790.0              No                27.0
# 17       170.0  4200.0        1350.0              No                23.0
# 18       300.0  5000.0        1450.0             Yes                20.0
#
#     Passengers  Length  Wheelbase  Width  Turn.circle  Rear.seat.room  \
# 11         5.0   182.0      101.0   66.0         38.0            25.0
# 12         5.0   184.0      103.0   68.0         39.0            26.0
# 13         4.0   193.0      101.0   74.0         43.0            25.0
# 14         6.0     NaN      108.0   71.0          NaN            28.5
# 15         7.0   178.0      110.0   74.0         44.0            30.5
# 16         8.0   194.0      111.0   78.0         42.0            33.5
# 17         6.0   214.0      116.0   77.0         42.0            29.5
# 18         2.0   179.0       96.0   74.0         43.0             NaN
#
#     Luggage.room  Weight Origin                  Make
# 11          13.0  2490.0    USA    Chevrolet Cavalier
# 12           NaN  2785.0    USA     Chevrolet Corsica
# 13          13.0  3240.0    USA      Chevrolet Camaro
# 14          16.0  3195.0    USA      Chevrolet Lumina
# 15           NaN  3715.0    USA  Chevrolet Lumina_APV
# 16           NaN  4025.0    USA       Chevrolet Astro
# 17          20.0  3910.0    USA     Chevrolet Caprice
# 18           NaN  3380.0    NaN    Chevrolet Corvette

# %%
# Solution

chevy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/v0/ywqslh_51dx3jnpnjr05wgsr0000gn/T/ipykernel_31549/372062578.py in <module>
#       1 # Solution
#       2
# ----> 3 chevy
#
# NameError: name 'chevy' is not defined

# %%
chevy = df[df.Manufacturer == 'Chevrolet']
chevy = df[df.Horsepower < 3.0]
chevy
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Type, Min.Price, Price, Max.Price, MPG.city, MPG.highway, AirBags, DriveTrain, Cylinders, EngineSize, Horsepower, RPM, Rev.per.mile, Man.trans.avail, Fuel.tank.capacity, Passengers, Length, Wheelbase, Width, Turn.circle, Rear.seat.room, Luggage.room, Weight, Origin, Make]
# Index: []

# %% [markdown]
# ---

# %% [markdown]
# # FINISH HIM
